# %%
import cv2
import numpy as np

from matplotlib import pyplot as plt

# %% [markdown]
# - Detect and localize a license plate in an input image.
# - Extract the characters from license plate.
# - Apply some form of Optical Character Recognition (OCR).

# %%
# Optionally add flags=0 for grayscale image read 
image = cv2.imread("../../data/plate0.png")
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2GRAY)
rgb_image = cv2.cvtColor(gray_image, cv2.COLOR_BGR2RGB)

plt.imshow(rgb_image)
plt.title("Original gray")
plt.show()

blurred_image = cv2.GaussianBlur(rgb_image, (3, 3), sigmaX=0, sigmaY=0)

plt.imshow(blurred_image)
plt.title("Blurred image")
plt.show()

# %%
sobel_x_image = cv2.Sobel(src=blurred_image, ddepth=cv2.CV_64F, dx=1, dy=0, ksize=5) # Sobel Edge Detection on the X axis
sobel_y_image = cv2.Sobel(src=blurred_image, ddepth=cv2.CV_64F, dx=0, dy=1, ksize=5) # Sobel Edge Detection on the Y axis
sobel_xy_image = cv2.Sobel(src=blurred_image, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=5) # Combined X and Y Sobel Edge Detection

sobel_x_image = np.clip(sobel_x_image, 0, 1)
sobel_y_image = np.clip(sobel_y_image, 0, 1)
sobel_xy_image = np.clip(sobel_xy_image, 0, 1)

plt.imshow(sobel_x_image)
plt.title("Sobel X")
plt.show()

plt.imshow(sobel_y_image)
plt.title("Sobel Y")
plt.show()

plt.imshow(sobel_xy_image)
plt.title("Sobel X/Y")
plt.show()

# %%
edges_image0 = cv2.Canny(image=blurred_image, threshold1=100, threshold2=200)

plt.imshow(edges_image0)
plt.title("Canny Edge Detection on Blurred Image")
plt.show()
